# %%
using Images, Colors, Plots, Wavelets, TestImages
# Out:
# INFO: Precompiling module TestImages.

# %%
function chaosgame_dnasequence(txtfile,res)
    display(txtfile)
    f = open(txtfile)
    lines = readlines(f)[2:end]
    close(f)
    
    #Read sequence into array, the first line of file is description
    sequence = reduce(*,"",map(strip,lines))
    sequence2 = ""
    for s in sequence
        if s != 'N'
            sequence2 *= s
        end
    end
    sequence = sequence2
    
    #Define bases on corners across from their pair
    codes = Dict('C'=>[0,1], 'T'=>[1,1], 'G'=>[1,0], 'A'=>[0,0])
    # codes = Dict('C'=>[0,1], 'A'=>[1,1], 'T'=>[1,0], 'G'=>[0,0])

    #Chaos game
    positions = zeros(2,length(sequence))
    positions[:,1] = [0.5,0.5] #start in the middle
    for i = 1:length(sequence)
        if i==1
            prev = [0.5,0.5]
        else
            prev = positions[:,i-1]
        end
        next = (prev+codes[sequence[i]])*0.5
        positions[:,i] = next
    end

    #Print image
    # res = 400
    A = ones(3, res, res)
    img = colorview(RGB, A)
    r,c = size(positions)
    for i = 1:c
        code = sequence[i]
        posn = ceil.(Int,positions[:,i]*res)
        img[posn...] = RGB(0,0,0)
    end
    img
end
# Out:
# chaosgame_dnasequence (generic function with 1 method)

# %%
img = chaosgame_dnasequence("cannabis/dagestani.txt",1000)
function boxcounting(img)
    # Scan over fixed regular box grid to determine which boxes contain fractal
    rows,cols = size(img)
    resolutions = [1,2,4,5,8,10,20,25,40,50]
    D = []
    for i = 1:length(resolutions)
        boxsize = resolutions[i]
        N = 0#number of boxes containing fractal
        T = 0#total number of boxes
        for x in collect(1:boxsize:rows)
            for y in collect(1:boxsize:cols)
                box = img[x:x+boxsize-1,y:y+boxsize-1]
                cover = sum(box .== RGB(0,0,0))
                if cover > 0
                    N += 1
                end
                T += 1
            end
        end 
        push!(D,(boxsize,N,T))
    end
    display(D)
    D
end
function plotboxcounting(D)
    # Plot log relationship between number of containing boxes
    logr = map(d -> log(d[1]),D)
    logN = map(d -> log(d[2]),D)
    # Least squares method to approximate slope
    logrmean = mean(logr)
    logNmean = mean(logN)
    m = sum((logr-logrmean).*(logN-logNmean))/sum((logr-logrmean).^2)
    println("Approximate fractal dimension is $(-m)")
    b = logNmean - m*logrmean
    p = plot(xlabel="log(r)",ylabel="log(N)")
    plot!(logr,logN)
    plot!(logr,m*logr+b+1)
end
D = boxcounting(img)
plotboxcounting(D)
# Out:
# "cannabis/dagestani.txt"
# 10-element Array{Any,1}:
#  (1, 128378, 1000000)
#  (2, 95371, 250000)
#  (4, 48820, 62500)
#  (5, 35306, 40000)
#  (8, 15416, 15625)
#  (10, 9970, 10000)
#  (20, 2500, 2500)
#  (25, 1600, 1600)
#  (40, 625, 625)
#  (50, 400, 400)
# Approximate fractal dimension is 1.5853068048672534
# <script src="file:///Users/martinpham/.julia/v0.6/Plots/src/backends/../../deps/plotly-latest.min.js"></script>    <div id="2b7c9f38-4df5-402f-b37f-3d299dd9eefb" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('2b7c9f38-4df5-402f-b37f-3d299dd9eefb');
#     Plotly.plot(PLOT, [{"showlegend":true,"mode":"lines","xaxis":"x","colorbar":{"title":""},"line":{"color":"rgba(0, 154, 250, 1.000)","shape":"linear","dash":"solid","width":1},"y":[11.762734315993836,11.4655298279956,10.79589534394695,10.471808200149228,9.643161210094203,9.207335862955883,7.824046010856292,7.3777589082278725,6.437751649736401,5.991464547107982],"type":"scatter","name":"y1","yaxis":"y","x":[0.0,0.6931471805599453,1.3862943611198906,1.6094379124341003,2.0794415416798357,2.302585092994046,2.995732273553991,3.2188758248682006,3.6888794541139363,3.912023005428146]},{"showlegend":true,"mode":"lines","xaxis":"x","colorbar":{"title":""},"line":{"color":"rgba(227, 111, 71, 1.000)","shape":"linear","dash":"solid","width":1},"y":[13.567417112132027,12.468566170015794,11.369715227899563,11.0159642375389,10.27086428578333,9.917113295422668,8.818262353306437,8.464511362945775,7.719411411190205,7.365660420829543],"type":"scatter","name":"y2","yaxis":"y","x":[0.0,0.6931471805599453,1.3862943611198906,1.6094379124341003,2.0794415416798357,2.302585092994046,2.995732273553991,3.2188758248682006,3.6888794541139363,3.912023005428146]}], {"showlegend":true,"xaxis":{"showticklabels":true,"gridwidth":0.5,"tickvals":[0.0,1.0,2.0,3.0],"visible":true,"ticks":"inside","range":[0.0,3.912023005428146],"domain":[0.061654272382618835,0.9934383202099737],"tickmode":"array","linecolor":"rgba(0, 0, 0, 1.000)","showgrid":true,"title":"log(r)","mirror":false,"tickangle":0,"showline":true,"gridcolor":"rgba(0, 0, 0, 0.100)","titlefont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":15},"tickcolor":"rgb(0, 0, 0)","ticktext":["0","1","2","3"],"zeroline":false,"type":"-","tickfont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":11},"zerolinecolor":"rgba(0, 0, 0, 1.000)","anchor":"y"},"paper_bgcolor":"rgba(255, 255, 255, 1.000)","annotations":[],"height":400,"margin":{"l":0,"b":20,"r":0,"t":20},"plot_bgcolor":"rgba(255, 255, 255, 1.000)","yaxis":{"showticklabels":true,"gridwidth":0.5,"tickvals":[6.0,8.0,10.0,12.0],"visible":true,"ticks":"inside","range":[5.991464547107982,13.567417112132027],"domain":[0.07581474190726165,0.9901574803149606],"tickmode":"array","linecolor":"rgba(0, 0, 0, 1.000)","showgrid":true,"title":"log(N)","mirror":false,"tickangle":0,"showline":true,"gridcolor":"rgba(0, 0, 0, 0.100)","titlefont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":15},"tickcolor":"rgb(0, 0, 0)","ticktext":["6","8","10","12"],"zeroline":false,"type":"-","tickfont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":11},"zerolinecolor":"rgba(0, 0, 0, 1.000)","anchor":"x"},"legend":{"bordercolor":"rgba(0, 0, 0, 1.000)","bgcolor":"rgba(255, 255, 255, 1.000)","font":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":11},"y":1.0,"x":1.0},"width":600});
#     </script>

# %%
# COLOUR IMAGE WITH 3D HILBERT CURVE MAPPED TO 2D HILBERT CURVE
# Pixels visited in CGR are coloured, others are left white
dagestani = chaosgame_dnasequence("cannabis/dagestani.txt",1024)
hilbert = load("hilbert.jpg")
A = zeros(3, 1024, 1024)
img = colorview(RGB4, A)
for i = 1:4
    idx = i:4:4096
    img[:,:] += hilbert[idx,idx]./4
end
hilbertresize = img

test = hilbertresize
bitarray = dagestani .== RGB(0,0,0) #find where pixels are black in CGR
r,c = size(bitarray)
for y = 1:r
    for x = 1:c
        if !bitarray[y,x]
            test[y,x] = RGB(1,1,1) #change to white to replicate CGR
        end 
    end
end
test
# Out:
# "cannabis/dagestani.txt"
# 1024×1024 ColorView{RGB4}(::Array{Float64,3}) with element type ColorTypes.RGB4{Float64}:
#  RGB4{Float64}(0.00196078,0.00196078,0.00196078)  …  RGB4{Float64}(0.990196,0.00588235,0.00196078)
#  RGB4{Float64}(0.00686275,0.00294118,0.00490196)     RGB4{Float64}(1.0,1.0,1.0)
#  RGB4{Float64}(0.0166667,0.00686275,0.000980392)     RGB4{Float64}(1.0,1.0,1.0)
#  RGB4{Float64}(0.0245098,0.00882353,0.00490196)      RGB4{Float64}(1.0,1.0,1.0)
#  RGB4{Float64}(0.0235294,0.0313726,0.0235294)        RGB4{Float64}(1.0,1.0,1.0)
#  RGB4{Float64}(0.0245098,0.0323529,0.0166667)     …  RGB4{Float64}(1.0,1.0,1.0)
#  RGB4{Float64}(0.0264706,0.0362745,0.0127451)        RGB4{Float64}(1.0,1.0,1.0)
#  RGB4{Float64}(1.0,1.0,1.0)                          RGB4{Float64}(0.97451,0.0333333,0.00588235)
#  RGB4{Float64}(0.0343137,0.0343137,0.00294118)       RGB4{Float64}(1.0,1.0,1.0)
#  RGB4{Float64}(0.0362745,0.0382353,0.00686275)       RGB4{Float64}(1.0,1.0,1.0)
#  RGB4{Float64}(0.0411765,0.0509804,0.00784314)    …  RGB4{Float64}(1.0,1.0,1.0)
#  RGB4{Float64}(1.0,1.0,1.0)                          RGB4{Float64}(1.0,1.0,1.0)
#  RGB4{Float64}(0.0529412,0.054902,0.00392157)        RGB4{Float64}(1.0,1.0,1.0)
#  ⋮                                                ⋱
#  RGB4{Float64}(1.0,1.0,1.0)                          RGB4{Float64}(0.533333,0.780392,0.917647)
#  RGB4{Float64}(1.0,1.0,1.0)                          RGB4{Float64}(0.537255,0.770588,0.915686)
#  RGB4{Float64}(1.0,1.0,1.0)                          RGB4{Float64}(0.535294,0.762745,0.911765)
#  RGB4{Float64}(1.0,1.0,1.0)                       …  RGB4{Float64}(0.539216,0.754902,0.915686)
#  RGB4{Float64}(0.464706,0.756863,0.901961)           RGB4{Float64}(0.538235,0.755882,0.89902)
#  RGB4{Float64}(1.0,1.0,1.0)                          RGB4{Float64}(0.541176,0.754902,0.9)
#  RGB4{Float64}(1.0,1.0,1.0)                          RGB4{Float64}(0.55,0.759804,0.897059)
#  RGB4{Float64}(1.0,1.0,1.0)                          RGB4{Float64}(0.557843,0.757843,0.89902)
#  RGB4{Float64}(1.0,1.0,1.0)                       …  RGB4{Float64}(0.559804,0.755882,0.885294)
#  RGB4{Float64}(1.0,1.0,1.0)                          RGB4{Float64}(0.558824,0.760784,0.886275)
#  RGB4{Float64}(1.0,1.0,1.0)                          RGB4{Float64}(0.559804,0.767647,0.889216)
#  RGB4{Float64}(1.0,1.0,1.0)                          RGB4{Float64}(0.559804,0.77549,0.885294)

# %%
dagestani = chaosgame_dnasequence("cannabis/dagestani.txt",512)
# Out:
# "cannabis/dagestani.txt"
# 512×512 Array{RGB{Float64},2}:
#  RGB{Float64}(0.0,0.0,0.0)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(1.0,1.0,1.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(1.0,1.0,1.0)
#  RGB{Float64}(0.0,0.0,0.0)  …  RGB{Float64}(1.0,1.0,1.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(1.0,1.0,1.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(1.0,1.0,1.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(1.0,1.0,1.0)
#  RGB{Float64}(0.0,0.0,0.0)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(1.0,1.0,1.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  ⋮                          ⋱
#  RGB{Float64}(0.0,0.0,0.0)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(1.0,1.0,1.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(1.0,1.0,1.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(1.0,1.0,1.0)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(1.0,1.0,1.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(1.0,1.0,1.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(1.0,1.0,1.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(1.0,1.0,1.0)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(1.0,1.0,1.0)     RGB{Float64}(0.0,0.0,0.0)

# %%
img = Gray.(dagestani)
# img = Gray.(testimage("lena"))
x = Float64.(img)
L = 2 #level of resolution
xts = wplotim(x,L,wavelet(WT.db2))
Gray.(xts)
# Out:
# 512×512 Array{Gray{Float64},2}:
#  Gray{Float64}(0.0601141)  …  Gray{Float64}(0.117561)
#  Gray{Float64}(0.0272305)     Gray{Float64}(0.248609)
#  Gray{Float64}(0.158955)      Gray{Float64}(0.256553)
#  Gray{Float64}(0.0942824)     Gray{Float64}(0.0526008)
#  Gray{Float64}(0.151479)      Gray{Float64}(0.358371)
#  Gray{Float64}(0.081908)   …  Gray{Float64}(0.0581729)
#  Gray{Float64}(0.366246)      Gray{Float64}(0.480117)
#  Gray{Float64}(0.451992)      Gray{Float64}(0.434129)
#  Gray{Float64}(0.104676)      Gray{Float64}(0.561286)
#  Gray{Float64}(0.256785)      Gray{Float64}(0.365182)
#  Gray{Float64}(0.391414)   …  Gray{Float64}(0.561286)
#  Gray{Float64}(0.547253)      Gray{Float64}(0.376851)
#  Gray{Float64}(0.31765)       Gray{Float64}(0.322737)
#  ⋮                         ⋱
#  Gray{Float64}(0.237577)   …  Gray{Float64}(0.510464)
#  Gray{Float64}(0.194244)      Gray{Float64}(0.132238)
#  Gray{Float64}(0.132238)      Gray{Float64}(0.0)
#  Gray{Float64}(0.121567)      Gray{Float64}(0.0)
#  Gray{Float64}(0.540057)      Gray{Float64}(0.332444)
#  Gray{Float64}(0.259434)   …  Gray{Float64}(0.434129)
#  Gray{Float64}(0.0526008)     Gray{Float64}(0.0900249)
#  Gray{Float64}(0.0581729)     Gray{Float64}(0.0)
#  Gray{Float64}(0.383518)      Gray{Float64}(0.0)
#  Gray{Float64}(0.117561)      Gray{Float64}(0.132238)
#  Gray{Float64}(0.652215)   …  Gray{Float64}(0.0358096)
#  Gray{Float64}(0.146246)      Gray{Float64}(0.0)

# %%
test = Float64.(Gray.(testimage("lena")))
wtest = dwt(test,wavelet(WT.haar))
iwtest = idwt(wtest,wavelet(WT.haar))
colorview(Gray,iwtest)
# Out:
# 256×256 Array{Gray{Float64},2}:
#  Gray{Float64}(0.635294)  Gray{Float64}(0.631373)  …  Gray{Float64}(0.552941)
#  Gray{Float64}(0.635294)  Gray{Float64}(0.631373)     Gray{Float64}(0.552941)
#  Gray{Float64}(0.639216)  Gray{Float64}(0.623529)     Gray{Float64}(0.454902)
#  Gray{Float64}(0.623529)  Gray{Float64}(0.619608)     Gray{Float64}(0.219608)
#  Gray{Float64}(0.607843)  Gray{Float64}(0.619608)     Gray{Float64}(0.180392)
#  Gray{Float64}(0.611765)  Gray{Float64}(0.615686)  …  Gray{Float64}(0.188235)
#  Gray{Float64}(0.615686)  Gray{Float64}(0.611765)     Gray{Float64}(0.192157)
#  Gray{Float64}(0.619608)  Gray{Float64}(0.615686)     Gray{Float64}(0.196078)
#  Gray{Float64}(0.611765)  Gray{Float64}(0.611765)     Gray{Float64}(0.196078)
#  Gray{Float64}(0.611765)  Gray{Float64}(0.611765)     Gray{Float64}(0.188235)
#  Gray{Float64}(0.611765)  Gray{Float64}(0.611765)  …  Gray{Float64}(0.2)
#  Gray{Float64}(0.615686)  Gray{Float64}(0.607843)     Gray{Float64}(0.207843)
#  Gray{Float64}(0.607843)  Gray{Float64}(0.603922)     Gray{Float64}(0.215686)
#  ⋮                                                 ⋱  ⋮
#  Gray{Float64}(0.2)       Gray{Float64}(0.301961)     Gray{Float64}(0.227451)
#  Gray{Float64}(0.172549)  Gray{Float64}(0.25098)   …  Gray{Float64}(0.211765)
#  Gray{Float64}(0.172549)  Gray{Float64}(0.219608)     Gray{Float64}(0.184314)
#  Gray{Float64}(0.192157)  Gray{Float64}(0.211765)     Gray{Float64}(0.211765)
#  Gray{Float64}(0.211765)  Gray{Float64}(0.223529)     Gray{Float64}(0.203922)
#  Gray{Float64}(0.203922)  Gray{Float64}(0.235294)     Gray{Float64}(0.188235)
#  Gray{Float64}(0.196078)  Gray{Float64}(0.219608)  …  Gray{Float64}(0.227451)
#  Gray{Float64}(0.192157)  Gray{Float64}(0.223529)     Gray{Float64}(0.309804)
#  Gray{Float64}(0.184314)  Gray{Float64}(0.203922)     Gray{Float64}(0.341176)
#  Gray{Float64}(0.196078)  Gray{Float64}(0.2)          Gray{Float64}(0.356863)
#  Gray{Float64}(0.172549)  Gray{Float64}(0.192157)     Gray{Float64}(0.384314)
#  Gray{Float64}(0.172549)  Gray{Float64}(0.207843)  …  Gray{Float64}(0.415686)
